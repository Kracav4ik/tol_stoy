# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import matplotlib


q1 = []
q2 = []
q3 = []
q4 = []
q = []


with open('defaults.txt') as f:
    lines = [l.strip() for l in f]

def fill_q(idx, q_):
    q_.append([
        float(lines[idx].split()[6][:-1]),
        float(lines[idx].split()[8][:-1]),
        float(lines[idx].split()[9][:-1]),
        float(lines[idx].split()[10][:-1]),
        float(lines[idx].split()[11][:-2]),
    ])

for i in range(16):
    fill_q(5*i+0, q1)
    fill_q(5*i+1, q2)
    fill_q(5*i+2, q3)
    fill_q(5*i+3, q4)
    q.append(float(lines[5*i+4].split()[5][:-1]))

x = list(range(16))
    
fig, ax = plt.subplots(figsize=(12, 8))
ax.get_yaxis().set_major_formatter(matplotlib.ticker.FuncFormatter(lambda x, p: '%s%%' % int(x)))
ax.set_ylim((0, 100))

plt.plot(x, [q1[i][1] for i in x], 's', label='мужской - женский род (глаголы)')
plt.plot(x, [q2[i][1] for i in x], 'v', label='мужской - женский род (остальные)')
plt.plot(x, [q3[i][1] for i in x], 'o', label='единственное - множественное число')
plt.plot(x, [q4[i][1] for i in x], 'D', label='антонимы с не-')
plt.xticks(np.arange(0, 16, 1))
plt.xlabel('Эпоха тренировки')
plt.ylabel('Правильные ответы')

legend=ax.legend(loc='center right')
